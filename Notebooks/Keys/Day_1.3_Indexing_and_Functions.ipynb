# %% [markdown]
# <a href="https://colab.research.google.com/github/grkenney/WinSPIRE-HLC-Python/blob/main/Notebooks/Keys/Day_1.3_Indexing_and_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lists
# Lists can be used to group different values together - it is just a collection of things.
#
# You can make a list in Python by putting different things in a box of brackets `[]` separated by commas:

# %%
# make a list and store it in my_list
my_list = ['pizza', 'fries', 3, -2.5, 'donuts']

# print my_list
print(my_list)
# Out:
# ['pizza', 'fries', 3, -2.5, 'donuts']

# %% [markdown]
# You can also see how many things there are in your list using `len`:

# %%
# find the length of my_list
len(my_list)
# Out:
# 5

# %% [markdown]
# **Exercise:** Try this out! Make a list of fruit and save it to the variable `fruit`. Have your list include apple, banana, grape, and kiwi!

# %%
# make a list of fruit including apple, banana, grape, and kiwi
fruit = ["apple", "banana", "grape", "kiwi"]

# command Python to print the list of fruit
print(fruit)
# Out:
# ['apple', 'banana', 'grape', 'kiwi']

# %% [markdown]
# Find the length of the `fruit` list:

# %%
# find the length of the list fruit
len(fruit)
# Out:
# 4

# %% [markdown]
# To add lists together, all you have to do is use the `+` operator.

# %%
# command python to add my_list and fruit
my_list + fruit
# Out:
# ['pizza', 'fries', 3, -2.5, 'donuts', 'apple', 'banana', 'grape', 'kiwi']

# %% [markdown]
# To add a value to a list, you can use `.append()`:

# %%
# append 4 to my_list
my_list.append(4)

# print my_list
print(my_list)
# Out:
# ['pizza', 'fries', 3, -2.5, 'donuts', 4]

# %% [markdown]
# Note that with append, we don't have to explicitly update the variable list. This is because append is a method of list objects and modifies the objects directly. We'll talk about methods more later in the lessons.

# %% [markdown]
# **Exercise:** Try adding mango to our fruit list:

# %%
# add mango to fruit list
fruit.append("mango")

# print fruit
print(fruit)
# Out:
# ['apple', 'banana', 'grape', 'kiwi', 'mango']

# %% [markdown]
# You can also make a list that includes variables:

# %%
# assign the value 1 to the variable a
a = 1

# assign the value 2 to the variable b
b = 2

# %%
# make a list including values and variables and save it to the variable numbers
numbers = [0, a, b, a+b]
# print the numbers list
print(numbers)
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# **Exercise:** Try duplicating the list of numbers. Try a few different ways of doing this, there are multiple correct answers!

# %%
# duplicate the list numbers
numbers + numbers
numbers * 2
# Out:
# [0, 1, 2, 3, 0, 1, 2, 3]

# %% [markdown]
# You just learned how to:
# * Make a list ([])
# * Find the length of a list (len)
# * Add lists together (+)
# * Add things to a list (.append)

# %% [markdown]
# # Indexing
# Now that we have been introduced to lists, we're going to talk about how to access different parts of the list using something called **indexing**.
#
# To index a list, you use square brackets (`[]`) with a number (or numbers) in the brackets specifying which elements of the list you want.
#
# Let's start with a list of fruit:

# %%
# make a list and store it fruit
fruit = ['apple', 'banana', 'grape', 'kiwi', 'mango']

# get the length of your list
len(fruit)
# Out:
# 5

# %% [markdown]
# Let's try getting the first element in the list:

# %%
# print one element of your list
print(fruit[1])
# Out:
# banana

# %% [markdown]
# Is this what you expected? If not, you're not alone. The trick is that Python starts counting at zero!
#
# Here's how you actually print the first element of the list:

# %%
# print the first element of your list
print(fruit[0])
# Out:
# apple

# %% [markdown]
# How do you think we can print the element mango in the list?

# %%
# print the element mango
print(fruit[4])
# Out:
# mango

# %% [markdown]
# Since we know mango is the last element in the list, can you think of another way we might print mango?

# %%
# print the last element in the list
print(fruit[4])
print(fruit[-1])
# Out:
# mango
# mango

# %% [markdown]
# We can also get more than one element of a list:

# %%
# get the first 3 elements of the list and save it to fruit_subset
fruit_subset = fruit[0:3]
print(fruit_subset)
# Out:
# ['apple', 'banana', 'grape']

# %%
# print the length of fruit_subset
len(fruit_subset)
# Out:
# 3

# %% [markdown]
# Note that in Python, the first number in indexing is *inclusive* and the second number is *exclusive*. In other words, you get the element corresponding to the first number (0), but not the element corresponding to the last number (3). This is like [0,3) in math.
#
# Let's print the second and third elements of the list:

# %%
# get the 2nd and 3rd elements of fruit
fruit[1:3]
# Out:
# ['banana', 'grape']

# %% [markdown]
# Now let's make a list of the second and fourth elment from fruit:

# %%
# print the second and fourth elements from the list
[fruit[1], fruit[3]]
# Out:
# ['banana', 'kiwi']

# %% [markdown]
# You can also get letters in a string by indexing!

# %%
# store the first element of fruit (apple) in the variable a
a = fruit[0]
a

# print the first 3 letters in apple
a[0:3]
# Out:
# 'app'

# %% [markdown]
# You just learned how to:
# * Get an element from a list or string
# * Get multiple elements from a list or string
#
# Now it's time to practice what you learned!

# %% [markdown]
# **Exercise**:
# * Create a list of at least 3 vegetables.
# * Add your list of vegetables to the list of fruit from above and store it in a variable named produce.
# * Find the length of produce.
# * Print the first and last elements of produce.
# * Pick your favorite item from the list produce and store it in a variable fav_produce.
# * Print the first 2 letters in fav_produce.
# * Print the last 2 letters in fav_produce.

# %%
vegetables = ["potato", "carrot", "green bean", "tomato"]
produce = fruit + vegetables
print(produce)
# Out:
# ['apple', 'banana', 'grape', 'kiwi', 'mango', 'potato', 'carrot', 'green bean', 'tomato']

# %%
len(produce)
# Out:
# 9

# %%
[produce[0], produce[-1]]
# Out:
# ['apple', 'tomato']

# %%
fav_produce = produce[6]
print(fav_produce[0:2])
print(fav_produce[4:6])
# Out:
# ca
# ot

# %% [markdown]
# # Functions and Methods
#
# Functions and methods are things that take an input, do something with that input, and then spit out an output. You've already been using functions and methods!
#
# Examples of functions:
# - `print`: prints the input out to the screen
# - `len`: finds the length of the input
#
# Example of a method:
# - `append`: appends elements to a list
#
# So what's the difference between functions and methods?
#
# Differences in input:
# - **Functions** can take lots of different object types as input. For example, print can take a variety of inputs including a variable, a string, a list, or numbers.
# - **Methods** can only be used on one specific type of object. For example, append can only be used on lists (and not strings or numbers).
#
# Differences in syntax (how we write it to use it):
# - The input to **functions** goes *between* parentheses after the name of function
#   - Example: `print(print_input)`
#
#
# - At least part of the input to **methods** comes *before* the name of the method and is followed by a period (`.`)
#   - Example: `mylist.append(what_to_append)`
#
# We're going to learn a few more functions and methods here!
#
# Let's start by learning some functions and methods we can use with lists of numbers!

# %%
# make a list of numbers
numbers = [10,2.3,-4,20,14,1,2,0,-3,1,-2,2,2,65.4,3,-23,123,43.1,32,57,32]

# %% [markdown]
# What function can you use to find the length of this list? Use this function to find the length:

# %%
# get the length of numbers
len(numbers)
# Out:
# 21

# %% [markdown]
# If you're not sure how to use a function, you can use the function `help` to get more information about it. Here's an example to find more information about length:

# %%
# use help to find more information about the function length
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# It tells you that len takes an object and returns the number of items in the object.
#
# To get the object type of `numbers` we can use the function `type`:

# %%
# print the type of numbers
type(numbers)
# Out:
# list

# %% [markdown]
# Nice! It's a list, just like we expected. What is the type of the first element in `numbers`?

# %%
# print the first element of numbers
print(numbers[0])

# print the type of the first element of numbers
type(numbers[0])
# Out:
# 10
# int

# %% [markdown]
# It's an integer. What about the type of the second element of numbers?

# %%
# print the second element of numbers
print(numbers[1])

# print the type of the second element of numbers
type(numbers[1])
# Out:
# 2.3
# float

# %% [markdown]
# It's a float. This means it has a decimal place (so it's not an integer).
#
# We can also find the absolute value of a number. Print the third element and then print the absolute value of this number using the function `abs`:

# %%
# print the third element of numbers
print(numbers[2])

# print the absolute value of the third element of numbers
abs(numbers[2])
# Out:
# -4
# 4

# %% [markdown]
# Now let's find the minimum of the numbers list using the function `min` and the maximum of the numbers list using the function `max`:

# %%
# print the minimum of the numbers list
print(min(numbers))

# print the maximum of the numbers list
print(max(numbers))
# Out:
# -23
# 123

# %% [markdown]
# We can also find the sum of all of the numbers in `numbers` using the function `sum`:

# %%
# print the sum of numbers
sum(numbers)
# Out:
# 377.8

# %% [markdown]
# What if we want to find the mean of this list? Hint: We can use the functions `sum` and `len` to do this.

# %%
# save the mean of the numbers list to the variable avg
avg = sum(numbers) / len(numbers)

# print avg
print(avg)
# Out:
# 17.99047619047619

# %% [markdown]
# What if we want to round this number so there aren't so many decimal places? We can use the function `round` to do this:

# %%
# round avg
round(avg)
# Out:
# 18

# %% [markdown]
# What if we want to include 2 decimal places when we round? We can use what's called an *argument* to tell the function that we want to do this. First, let's look at the help description for `round`:

# %%
# get help for round function
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %% [markdown]
# It says that the default number of digits to round to is zero, but you can also give an argument to specify the number of digits. To add an argument, you put a comma after the input and then the argument. Let's try it out!

# %%
# print avg rounded to 2 decimal places
round(avg, 2)
# Out:
# 17.99

# %% [markdown]
# Nice job! You just learned about functions in Python! You learned:
# - What functions and methods do
# - The difference between functions and methods
# - How to learn more about a certain function or method (using the `help` function)
# - New functions: `max`, `min`, `sum`, `abs`, `round`
# - Functions can take arguments that modify the output

# %% [markdown]
# **Exercise**:
# Now let's try exploring some new methods. We can also use the help function to learn about each method before trying it out.
# * Look at the help on the list object to learn about the different methods available. (these will be towards the bottom of help info)
# * Use the `index` method to learn which index the string grape is at in the list
# * Use the `pop` to remove grape from the list of fruit
# * Use `append` to add grape back to the list
# * Now, use `sort` to put the list in alphabetical order
# * Use the `insert` method to insert cherry in the correct alphabetical position without sorting the list.

# %%
# make a list and store it fruit
fruit = ['apple', 'banana', 'grape', 'kiwi', 'mango']

# %%
# print help information for list objects to see available methods
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the list.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the list in memory, in bytes.
#  |
#  |  append(self, object, /)
#  |      Append object to the end of the list.
#  |
#  |  clear(self, /)
#  |      Remove all items from list.
#  |
#  |  copy(self, /)
#  |      Return a shallow copy of the list.
#  |
#  |  count(self, value, /)
#  |      Return number of occurrences of value.
#  |
#  |  extend(self, iterable, /)
#  |      Extend list by appending elements from the iterable.
#  |
#  |  index(self, value, start=0, stop=9223372036854775807, /)
#  |      Return first index of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(self, index, object, /)
#  |      Insert object before index.
#  |
#  |  pop(self, index=-1, /)
#  |      Remove and return item at index (default last).
#  |
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(self, value, /)
#  |      Remove first occurrence of value.
#  |
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(self, /)
#  |      Reverse *IN PLACE*.
#  |
#  |  sort(self, /, *, key=None, reverse=False)
#  |      Sort the list in ascending order and return None.
#  |
#  |      The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#  |      order of two equal elements is maintained).
#  |
#  |      If a key function is given, apply it once to each list item and sort them,
#  |      ascending or descending, according to their function values.
#  |
#  |      The reverse flag can be set to sort in descending order.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
# find the index of grape with the method index
fruit.index("grape")
# Out:
# 2

# %%
# remove grape from the list of fruit using pop
fruit.pop(2)
# Out:
# 'grape'

# %%
# add grape back to the list of fruit with append
fruit.append("grape")

# %%
# print the list to check
print(fruit)
# Out:
# ['apple', 'banana', 'kiwi', 'mango', 'grape']

# %%
# use sort to sort the list in alphabetical order
fruit.sort()

# %%
# print the list to check
print(fruit)
# Out:
# ['apple', 'banana', 'grape', 'kiwi', 'mango']

# %%
# use insert to insert cherry at the 3rd position
fruit.insert(2, "cherry")

# %%
# print the list to check
print(fruit)
# Out:
# ['apple', 'banana', 'cherry', 'grape', 'kiwi', 'mango']
