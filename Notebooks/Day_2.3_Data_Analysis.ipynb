# %% [markdown]
# <a href="https://colab.research.google.com/github/grkenney/WinSPIRE-HLC-Python/blob/main/Notebooks/Day_2.3_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # group by functions etc.

# %%
import pandas as pd

# %% [markdown]
# independent working with the data

# %% [markdown]
# saving pandas df to their drive

# %%
url = "https://github.com/grkenney/WinSPIRE-HLC-Python/raw/refs/heads/main/data/meta_data_expression_06092026.csv"

# load in the above url into a pandas data frame in a variable called "meta"
meta = pd.read_csv(url)
meta
# Out:
#     sample_id treatment_group
# 0      657317         Control
# 1      407401         Control
# 2      835249         control
# 3      490084       Treatment
# 4      452567       Treatment
# 5      480918         Control
# 6      994571       Treatment
# 7      248286       Treatment
# 8      840149       Treatment
# 9      804190       Treatment
# 10     993751         Control
# 11     403695         Control
# 12     336989         control
# 13     263925         Control
# 14     318517         Control
# 15     273129         Control
# 16     994861       Treatment
# 17     248138       Treatment
# 18     266888         Control
# 19     769101       Treatment
# 20     492993         control
# 21     569324       Treatment
# 22     917531       Treatment
# 23     870332       Treatment
# 24     872920         Control
# 25     611879       Treatment
# 26     639327       Treatment
# 27     123878         Control
# 28     199598       Treatment
# 29     871144         Control

# %%
# get the head of the data frame

# %%
# how many columns and what are they?

# %%
# what data types are in each column?

# %%
# what are the unique values in the treatment_group column?
meta["treatment_group"].unique()
# Out:
# array(['Control', 'control', 'Treatment'], dtype=object)

# %%
# make sure you save your data frame!
